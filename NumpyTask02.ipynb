# %%
import numpy as np
from PIL import Image

# %%
img = Image.open("hamza.jpg")
img1 = np.array(img)

# %%
img1.shape
# Out:
# (853, 853, 3)

# %%
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
image = image.imread('hamza.jpg')
# summarize shape of the pixel array
print(image.dtype)
print(image.shape)
# display the array of pixels as an image
pyplot.imshow(image)
pyplot.show()
# Out:
# uint8
# (853, 853, 3)

# %%
from numpy import asarray
# load the image
image = Image.open('hamza.jpg')
# convert image to numpy array
data = asarray(image)
print(type(data))
# summarize shape
print(data.shape)

# create Pillow image
image2 = Image.fromarray(data)
print(type(image2))

# summarize image details
print(image2.mode)
print(image2.size)
# Out:
# <class 'numpy.ndarray'>
# (853, 853, 3)
# <class 'PIL.Image.Image'>
# RGB
# (853, 853)

# %%
print(data)
# Out:
# [[[196 196 208]
#   [196 196 208]
#   [196 196 208]
#   ...
#   [137 128 149]
#   [143 134 155]
#   [134 125 146]]
#
#  [[196 196 208]
#   [196 196 208]
#   [196 196 208]
#   ...
#   [131 122 143]
#   [137 128 149]
#   [130 121 142]]
#
#  [[196 196 208]
#   [196 196 208]
#   [196 196 208]
#   ...
#   [122 113 134]
#   [128 119 140]
#   [121 112 133]]
#
#  ...
#
#  [[ 42  43  29]
#   [ 42  43  29]
#   [ 41  42  28]
#   ...
#   [ 95  92 111]
#   [ 97  94 113]
#   [ 98  95 114]]
#
#  [[ 43  44  30]
#   [ 42  43  29]
#   [ 42  43  29]
#   ...
#   [ 98  95 114]
#   [ 99  96 115]
#   [100  97 116]]
#
#  [[ 43  44  30]
#   [ 43  44  30]
#   [ 42  43  29]
#   ...
#   [ 99  96 115]
#   [100  97 116]
#   [101  98 117]]]

# %%
final = data[0:3,0:3,0]

# %%
print(final)
# Out:
# [[196 196 196]
#  [196 196 196]
#  [196 196 196]]

# %%
Filter = [[-1,0,1],
          [-1,0,1],
          [-1,0,1]]

# %%
test = final * Filter

# %%
final_image2 = Image.fromarray(test)
final_image2.save("finalpic1.jpg")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\JpegImagePlugin.py in _save(im, fp, filename)
#     614     try:
# --> 615         rawmode = RAWMODE[im.mode]
#     616     except KeyError:
#
# KeyError: 'I'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-56-9dbd869718ea> in <module>
#       1 final_image2 = Image.fromarray(test)
# ----> 2 final_image2.save("finalpic1.jpg")
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2100
#    2101         try:
# -> 2102             save_handler(self, fp, filename)
#    2103         finally:
#    2104             # do what we can to clean up
#
# ...

# %%
for i in range(len(Filter)):
    for j in range(len(data[0])):
         for k in range(len(Filter)): 
            result[i][j][k] += data[i][k][k] * Filter[i][k][j]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-b3ec6632e7c0> in <module>
#       2     for j in range(len(data[0])):
#       3          for k in range(len(Filter)):
# ----> 4             result[i][j][k] += data[i][k][k] * Filter[i][k][j]
#
# TypeError: 'int' object is not subscriptable

# %%
Filter * data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-84fa2ed6f49d> in <module>
# ----> 1 Filter * data
#
# ValueError: operands could not be broadcast together with shapes (3,3) (853,853,3)

# %%
filter_list = type(Filter)
filter_list
# Out:
# list

# %%
data_list=data.tolist()

# %%
finalOutput = result * data_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-910abacc01a3> in <module>
# ----> 1 finalOutput = result * data_list
#
# TypeError: can't multiply sequence by non-int of type 'list'
